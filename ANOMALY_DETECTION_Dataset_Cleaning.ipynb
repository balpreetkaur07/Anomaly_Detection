# %%
# Load and combine data

import os
import pandas as pd

df = pd.DataFrame(columns=[' Destination Port', ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std', 'Bwd Packet Length Max', ' Bwd Packet Length Min', ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size', ' Avg Fwd Segment Size', ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward', ' Init_Win_bytes_backward', ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min', ' Label'])

for dirname, _, filenames in os.walk('/home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning'):
    for filename in filenames:
        path = os.path.join(dirname, filename)
        print("Loading data from", path)
        df_temp = pd.read_csv(path)
        df = df.append(df_temp, ignore_index = True)
#df = pd.read_csv('/home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/fridaydata.csv')        
df
# Out:
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Friday-WorkingHours-Morning.pcap_ISCX.csv
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Monday-WorkingHours.pcap_ISCX.csv
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Tuesday-WorkingHours.pcap_ISCX.csv
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# Loading data from /home/ai/Downloads/Anomaly_detection/ANOMALY_DETECTION_Project/DATASET_bundle_archive/MachingLearning/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# ...

# %%
# Remove whitespace from column names 

df = df.rename(columns=lambda x: x.strip())

# Change column types to int64 (except label and those with float64)

cols = df.select_dtypes(include=['object']).columns.drop('Label')
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542141 entries, 0 to 2542140
# Data columns (total 79 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Backward Packets       int64
#  4   Total Length of Fwd Packets  int64
#  5   Total Length of Bwd Packets  int64
#  6   Fwd Packet Length Max        int64
#  7   Fwd Packet Length Min        int64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        int64
#  11  Bwd Packet Length Min        int64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
# ...

# %%
#df.to_csv('combined_data.csv', index=False)

# %%
# Check original breakdown of classes

df['Label'].value_counts()
# Out:
# BENIGN                        1984531
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# FTP-Patator                      7938
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1966
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: Label, dtype: int64

# %%
# Check for rows with inf and NaN since they are useless and drop them

import numpy as np

df = df.replace([np.inf, -np.inf], np.nan)
df.isnull().sum()  

df = df.dropna()
df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0              3268      112740690                 32                      16
# 1               389      112740560                 32                      16
# 2                 0      113757377                545                       0
# 3              5355         100126                 22                       0
# 4                 0          54760                  4                       0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         6448                         1152
# 1                         6448                         5056
# 2                            0                            0
# 3                          616                            0
# 4                            0                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...

# %%
# Check value counts of certain attributes

print(df['Destination Port'].value_counts().head(10), '\n')

print(df['Flow Bytes/s'].value_counts().head(10), '\n')

print(df['Total Length of Bwd Packets'].value_counts().head(10), '\n')

print(df['Flow Packets/s'].value_counts().head(10), '\n')

print(df['Flow Duration'].value_counts().head(10), '\n')

print(df['FIN Flag Count'].value_counts().head(10), '\n')

print(df['Down/Up Ratio'].value_counts().head(10), '\n')

print(df['Bwd Avg Bytes/Bulk'].value_counts().head(10), '\n')
# Out:
# 53     858660
# 80     591995
# 443    453579
# 123     22926
# 22      15612
# 21      12729
# 137      7071
# 389      5666
# 88       5127
# 465      3384
# Name: Destination Port, dtype: int64
#
# 0.000000e+00    330709
# 4.000000e+06     19941
# 3.000000e+06      8239
# 1.233333e+07      7592
# 1.818182e+05      6756
# 1.860465e+05      6667
# 1.363636e+05      6473
# 1.395349e+05      6409
# 9.250000e+06      5860
# 1.030000e+07      5603
# Name: Flow Bytes/s, dtype: int64
#
# 0        623041
# 6        263718
# 11595    154877
# 11607     42879
# 11601     38474
# 46        27226
# 96        22407
# 204       15688
# 264       15257
# 188       14846
# Name: Total Length of Bwd Packets, dtype: int64
#
# 6.666667e+05    53674
# 5.000000e+05    37680
# 2.000000e+06    24954
# 6.666667e+05    20467
# 4.651163e+04    14055
# 4.545455e+04    13501
# 4.081633e+04    12622
# 4.166667e+04    11482
# 1.000000e+06    10885
# 4.761905e+04     7360
# Name: Flow Packets/s, dtype: int64
#
# ...

# %%
# See breakdown for data types to see what needs to be corrected/normalized

pd.set_option('display.max_columns', 100)
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.539481e+06   2.539481e+06       2.539481e+06
# mean       8.047390e+03   1.546157e+07       9.725120e+00
# std        1.835882e+04   3.423120e+07       7.910971e+02
# min        0.000000e+00  -1.300000e+01       1.000000e+00
# 25%        5.300000e+01   1.670000e+02       1.000000e+00
# 50%        8.000000e+01   3.468900e+04       2.000000e+00
# 75%        4.430000e+02   4.330352e+06       5.000000e+00
# max        6.553500e+04   1.200000e+08       2.197590e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            2.539481e+06                 2.539481e+06
# mean             1.087843e+01                 5.479482e+02
# std              1.052362e+03                 5.846809e+03
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 1.200000e+01
# 50%              2.000000e+00                 6.300000e+01
# ...

# %%
# Replace -1 in Init_Win_bytes_forward and Init_Win_bytes_backward with 0
# Explanation can be found in CIC flowmeter github issues (https://github.com/ahlashkari/CICFlowMeter/issues/21)

df['Init_Win_bytes_forward'] = df['Init_Win_bytes_forward'].replace(-1, 0)
df['Init_Win_bytes_backward'] = df['Init_Win_bytes_backward'].replace(-1, 0)

# %% [markdown]
# we are commenting the 'label' drop line as we don't want to drop it now and will drop it later.

# %%
# Check for rows with negative values since we shouldn't have any
# (i.e. flow duration, flow bytes/s, flow packets/s, fwd header length, etc.)

cols = df.columns.drop('Label')
df[cols].lt(0).sum().to_frame().T
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                 0            111                  0                       0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                            0                            0
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                      0                      0                       0
#
#    Fwd Packet Length Std  Bwd Packet Length Max  Bwd Packet Length Min  \
# 0                      0                      0                      0
#
#    Bwd Packet Length Mean  Bwd Packet Length Std  Flow Bytes/s  \
# 0                       0                      0            81
#
#    Flow Packets/s  Flow IAT Mean  Flow IAT Std  Flow IAT Max  Flow IAT Min  \
# 0             111            111             0           111          2537
#
#    Fwd IAT Total  Fwd IAT Mean  Fwd IAT Std  Fwd IAT Max  Fwd IAT Min  \
# ...

# %%
# Remove all rows with negative values in them where it doesn't make sense 

df.loc[df['Flow Duration'] < 0, 'Flow Duration'] = np.nan
df.loc[df['Flow Bytes/s'] < 0, 'Flow Bytes/s'] = np.nan
df.loc[df['Flow Packets/s'] < 0, 'Flow Packets/s'] = np.nan
df.loc[df['Flow IAT Mean'] < 0, 'Flow IAT Mean'] = np.nan
df.loc[df['Flow IAT Max'] < 0, 'Flow IAT Max'] = np.nan
df.loc[df['Flow IAT Min'] < 0, 'Flow IAT Min'] = np.nan
df.loc[df['Fwd IAT Min'] < 0, 'Fwd IAT Min'] = np.nan
df.loc[df['Fwd Header Length'] < 0, 'Fwd Header Length'] = np.nan
df.loc[df['Bwd Header Length'] < 0, 'Bwd Header Length'] = np.nan
df.loc[df['min_seg_size_forward'] < 0, 'min_seg_size_forward'] = np.nan

df = df.dropna()

#cols = df.columns.drop('Label')
#df[cols].lt(0).sum().to_frame().T

# %%
#checking columns
df
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 0                    3268    112740690.0                 32
# 1                     389    112740560.0                 32
# 2                       0    113757377.0                545
# 3                    5355       100126.0                 22
# 4                       0        54760.0                  4
# ...                   ...            ...                ...
# 2542136                53        32215.0                  4
# 2542137                53          324.0                  2
# 2542138             58030           82.0                  2
# 2542139                53      1048635.0                  6
# 2542140                53        94939.0                  4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                            16                         6448
# 1                            16                         6448
# ...

# %%
#df.to_csv('combined_data1.csv', index=False)

# %%
#import pandas as pd
#df = pd.read_csv("/content/combined_data1.csv")

# %%
# Divide port numbers into 3 categories:
# well known (0 to 1023), registered (1024 to 49151), or dynamic ports (49152 to 65535)
# To do this, we don't need to include dynamic ports as a column since it can be deduced from its absence from the former two


#df['is_well_known_port'] = df.apply(lambda row: 1 if row['Destination Port'] < 1024 else 0, axis=1)
#df['is_registered_port'] = df.apply(lambda row: 1 if row['Destination Port'] >= 1024 and row['Destination Port'] < 49152 else 0, axis=1)

# %%
# Remove columns that aren't used

#df = df.drop(columns = ['Destination Port', 'Fwd Header Length.1'], axis=1)

# %%
list(df.columns)
# Out:
# ['Destination Port',
#  'Flow Duration',
#  'Total Fwd Packets',
#  'Total Backward Packets',
#  'Total Length of Fwd Packets',
#  'Total Length of Bwd Packets',
#  'Fwd Packet Length Max',
#  'Fwd Packet Length Min',
#  'Fwd Packet Length Mean',
#  'Fwd Packet Length Std',
#  'Bwd Packet Length Max',
#  'Bwd Packet Length Min',
#  'Bwd Packet Length Mean',
#  'Bwd Packet Length Std',
#  'Flow Bytes/s',
#  'Flow Packets/s',
#  'Flow IAT Mean',
#  'Flow IAT Std',
#  'Flow IAT Max',
#  'Flow IAT Min',
#  'Fwd IAT Total',
#  'Fwd IAT Mean',
#  'Fwd IAT Std',
#  'Fwd IAT Max',
#  'Fwd IAT Min',
#  'Bwd IAT Total',
#  'Bwd IAT Mean',
#  'Bwd IAT Std',
#  'Bwd IAT Max',
#  'Bwd IAT Min',
#  'Fwd PSH Flags',
#  'Bwd PSH Flags',
#  'Fwd URG Flags',
#  'Bwd URG Flags',
#  'Fwd Header Length',
#  'Bwd Header Length',
#  'Fwd Packets/s',
#  'Bwd Packets/s',
#  'Min Packet Length',
#  'Max Packet Length',
#  'Packet Length Mean',
#  'Packet Length Std',
#  'Packet Length Variance',
# ...

# %%
len(df.columns)
# Out:
# 79

# %%
# Remove colums with same value in every row
# df = df.drop(columns = ['Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length', 'Bwd Header Length', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk'], axis=1) 
df = df.drop(columns = ['Bwd PSH Flags', 'Bwd URG Flags', 'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate'], axis=1)
#for col in list(df.columns):
#    if df[col].max() == df[col].min():
#       print(col)
#       df = df.drop(col, axis=1)

list(df.columns)
# Out:
# ['Destination Port',
#  'Flow Duration',
#  'Total Fwd Packets',
#  'Total Backward Packets',
#  'Total Length of Fwd Packets',
#  'Total Length of Bwd Packets',
#  'Fwd Packet Length Max',
#  'Fwd Packet Length Min',
#  'Fwd Packet Length Mean',
#  'Fwd Packet Length Std',
#  'Bwd Packet Length Max',
#  'Bwd Packet Length Min',
#  'Bwd Packet Length Mean',
#  'Bwd Packet Length Std',
#  'Flow Bytes/s',
#  'Flow Packets/s',
#  'Flow IAT Mean',
#  'Flow IAT Std',
#  'Flow IAT Max',
#  'Flow IAT Min',
#  'Fwd IAT Total',
#  'Fwd IAT Mean',
#  'Fwd IAT Std',
#  'Fwd IAT Max',
#  'Fwd IAT Min',
#  'Bwd IAT Total',
#  'Bwd IAT Mean',
#  'Bwd IAT Std',
#  'Bwd IAT Max',
#  'Bwd IAT Min',
#  'Fwd PSH Flags',
#  'Fwd URG Flags',
#  'Fwd Header Length',
#  'Bwd Header Length',
#  'Fwd Packets/s',
#  'Bwd Packets/s',
#  'Min Packet Length',
#  'Max Packet Length',
#  'Packet Length Mean',
#  'Packet Length Std',
#  'Packet Length Variance',
#  'FIN Flag Count',
#  'SYN Flag Count',
# ...

# %%
len(df.columns)
# Out:
# 70

# %%
df
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 0                    3268    112740690.0                 32
# 1                     389    112740560.0                 32
# 2                       0    113757377.0                545
# 3                    5355       100126.0                 22
# 4                       0        54760.0                  4
# ...                   ...            ...                ...
# 2542136                53        32215.0                  4
# 2542137                53          324.0                  2
# 2542138             58030           82.0                  2
# 2542139                53      1048635.0                  6
# 2542140                53        94939.0                  4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                            16                         6448
# 1                            16                         6448
# ...

# %%
# Save unscaled data into a new master CSV

df.to_csv('cleaned_df_multilabel.csv', index=False)

# %%
#import pandas as pd
#df = pd.read_csv("/content/cleaned_df_multilabel.csv")

# %%
# Relabel benign data as 0 and everything else as 1

df['is_attack'] = df.apply(lambda row: 0 if row['Label'] == 'BENIGN' else 1, axis=1)
df = df.drop('Label', axis=1)

# %%
  df
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 0                    3268    112740690.0                 32
# 1                     389    112740560.0                 32
# 2                       0    113757377.0                545
# 3                    5355       100126.0                 22
# 4                       0        54760.0                  4
# ...                   ...            ...                ...
# 2542136                53        32215.0                  4
# 2542137                53          324.0                  2
# 2542138             58030           82.0                  2
# 2542139                53      1048635.0                  6
# 2542140                53        94939.0                  4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                            16                         6448
# 1                            16                         6448
# ...

# %%
# Save unscaled data into a new master CSV

df.to_csv('cleaned_df.csv', index=False)
df.describe()
# Out:
#        Destination Port  Flow Duration  Total Fwd Packets  \
# count      2.536909e+06   2.536909e+06       2.536909e+06
# mean       8.052667e+03   1.541880e+07       5.746349e+00
# std        1.836412e+04   3.418628e+07       7.736479e+01
# min        0.000000e+00   1.000000e+00       1.000000e+00
# 25%        5.300000e+01   1.670000e+02       1.000000e+00
# 50%        8.000000e+01   3.434400e+04       2.000000e+00
# 75%        4.430000e+02   4.259375e+06       5.000000e+00
# max        6.553500e+04   1.200000e+08       1.121410e+05
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# count            2.536909e+06                 2.536909e+06
# mean             5.567395e+00                 5.246206e+02
# std              1.075734e+02                 4.062111e+03
# min              0.000000e+00                 0.000000e+00
# 25%              1.000000e+00                 1.200000e+01
# 50%              2.000000e+00                 6.200000e+01
# ...

# %%
df
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 0                    3268    112740690.0                 32
# 1                     389    112740560.0                 32
# 2                       0    113757377.0                545
# 3                    5355       100126.0                 22
# 4                       0        54760.0                  4
# ...                   ...            ...                ...
# 2542136                53        32215.0                  4
# 2542137                53          324.0                  2
# 2542138             58030           82.0                  2
# 2542139                53      1048635.0                  6
# 2542140                53        94939.0                  4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 0                            16                         6448
# 1                            16                         6448
# ...
